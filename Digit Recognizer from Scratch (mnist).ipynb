# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

# %%
data = pd.read_csv('/kaggle/input/digit-recognizer/train.csv')

# %%
data = np.array(data)
m, n = data.shape
np.random.shuffle(data)

data_dev = data[0:1000].T
Y_dev = data_dev[0]
X_dev = data_dev[1:n]
X_dev = X_dev / 255.

data_train = data[1000:m].T
Y_train = data_train[0]
X_train = data_train[1:n]
X_train = X_train / 255.
_, m_train = X_train.shape

# %%
def params():
    w1 = np.random.rand(10, 784) - 0.5
    b1 = np.random.rand(10, 1) - 0.5

    w2 = np.random.rand(10, 10) - 0.5
    b2 = np.random.rand(10, 1) - 0.5

    w3 = np.random.rand(10, 10) - 0.5
    b3 = np.random.rand(10, 1) - 0.5

    return w1, b1, w2, b2, w3, b3

def ada_act(z, k0, k1):
    return k0 + k1*z

def softmax(z):
    a = np.exp(z) / sum(np.exp(z))
    return a

def forward_propagation(w1, b1, w2, b2, w3, b3, X, k0, k1):
    z1 = w1.dot(X) + b1
    a1 = ada_act(z1, k0, k1)

    z2 = w2.dot(a1) + b2
    a2 = ada_act(z2, k0, k1)

    z3 = w3.dot(a2) + b3
    a3 = softmax(z3)

    return z1, a1, z2, a2, z3, a3

def one_hot(Y):
    one_hot_Y = np.zeros((Y.size, Y.max() + 1))
    one_hot_Y[np.arange(Y.size), Y] = 1
    one_hot_Y = one_hot_Y.T
    return one_hot_Y

def back_propagation(X, Y, z1, a1, z2, a2, z3, a3, w1, b1, w2, b2, w3, b3, k0, k1):
    t = X.shape[1]
    one_hot_Y = one_hot(Y)

    dz3 = a3 - one_hot_Y
    dw3 = (1 / t) * dz3.dot(a2.T)
    db3 = np.mean(dz3, axis=1, keepdims=True)

    da2 = w3.T.dot(dz3)
    dz2 = k1 * da2
    dw2 = (1 / t) * dz2.dot(a1.T)
    db2 = np.mean(dz2, axis=1, keepdims=True)

    dK2 = np.mean(da2 * z2, axis=1)

    da1 = w2.T.dot(dz2)
    dz1 = k1 * da1
    dw1 = (1 / t) * dz1.dot(X.T)
    db1 = np.mean(dz1, axis=1, keepdims=True)

    dK1 = np.mean(da1 * z1, axis=1)

    dK = dK2 + dK1

    return dw1, db1, dw2, db2, dw3, db3, dK

def update_params(w1, b1, w2, b2, w3, b3, dW1, db1, dW2, db2, dW3, db3, dK, k0, k1, alpha):
    w1 -= alpha * dW1
    b1 -= alpha * db1
    w2 -= alpha * dW2
    b2 -= alpha * db2
    w3 -= alpha * dW3
    b3 -= alpha * db3

    k0 -= alpha * np.mean(dK)
    k1 -= alpha * np.mean(dK)

    return w1, b1, w2, b2, w3, b3, k0, k1

# %%
def get_predictions(a3):
    return np.argmax(a3, axis = 0)

def get_accuracy(predictions, Y):
    return np.sum(predictions == Y) / Y.size

def cross_entropy_loss(y_pred, y_true):
    y_pred = np.clip(y_pred, 1e-10, 1 - 1e-10)
    t = y_true.shape[0]
    return -np.sum(y_true * np.log(y_pred)) / t

def gradient_descent(X_train, Y_train, X_dev, Y_dev, iterations, alpha):
    w1, b1, w2, b2, w3, b3 = params()
    k0 = 0
    k1 = 1

    train_losses = []
    dev_losses = []
    train_accuracies = []
    dev_accuracies = []

    for i in range(iterations):
        z1, a1, z2, a2, z3, a3 = forward_propagation(w1, b1, w2, b2, w3, b3, X_train, k0, k1)
        loss_train = cross_entropy_loss(a3, one_hot(Y_train))
        predictions_train = get_predictions(a3)
        accuracy_train = get_accuracy(predictions_train, Y_train)

        _, _, _, _, _, a3_dev = forward_propagation(w1, b1, w2, b2, w3, b3, X_dev, k0, k1)
        loss_dev = cross_entropy_loss(a3_dev, one_hot(Y_dev))
        predictions_dev = get_predictions(a3_dev)
        accuracy_dev = get_accuracy(predictions_dev, Y_dev)

        train_losses.append(loss_train)
        train_accuracies.append(accuracy_train)
        dev_losses.append(loss_dev)
        dev_accuracies.append(accuracy_dev)

        dW1, db1, dW2, db2, dW3, db3, dK = back_propagation(X_train, Y_train, z1, a1, z2, a2, z3, a3, w1, b1, w2, b2, w3, b3, k0, k1)
        w1, b1, w2, b2, w3, b3, k0, k1 = update_params(w1, b1, w2, b2, w3, b3, dW1, db1, dW2, db2, dW3, db3, dK, k0, k1, alpha)

        if i % 10 == 0:
            print(f"Iteration {i}: \nTrain Loss = {loss_train:.3f}, Dev Loss = {loss_dev:.3f}, \nTrain Accuracy = {accuracy_train:.3f}, Dev Accuracy = {accuracy_dev:.3f}")

    return w1, b1, w2, b2, w3, b3, k0, k1, train_losses, dev_losses, train_accuracies, dev_accuracies

# %%
w1, b1, w2, b2, w3, b3, k0, k1, train_losses, dev_losses, train_accuracies, dev_accuracies = gradient_descent(X_train, Y_train, X_dev, Y_dev, 500, 0.1)
# Out:
# Iteration 0:
# Train Loss = 17458.626, Dev Loss = 423.558,
# Train Accuracy = 0.178, Dev Accuracy = 0.171
# Iteration 10:
# Train Loss = 7625.831, Dev Loss = 184.222,
# Train Accuracy = 0.355, Dev Accuracy = 0.353
# Iteration 20:
# Train Loss = 6513.921, Dev Loss = 158.177,
# Train Accuracy = 0.456, Dev Accuracy = 0.445
# Iteration 30:
# Train Loss = 5645.351, Dev Loss = 138.589,
# Train Accuracy = 0.544, Dev Accuracy = 0.527
# Iteration 40:
# Train Loss = 4971.344, Dev Loss = 123.723,
# Train Accuracy = 0.602, Dev Accuracy = 0.587
# Iteration 50:
# Train Loss = 4475.761, Dev Loss = 112.698,
# Train Accuracy = 0.641, Dev Accuracy = 0.623
# Iteration 60:
# Train Loss = 4107.762, Dev Loss = 104.274,
# Train Accuracy = 0.671, Dev Accuracy = 0.658
# Iteration 70:
# Train Loss = 3822.860, Dev Loss = 97.559,
# Train Accuracy = 0.696, Dev Accuracy = 0.680
# Iteration 80:
# Train Loss = 3593.709, Dev Loss = 92.032,
# Train Accuracy = 0.715, Dev Accuracy = 0.703
# Iteration 90:
# Train Loss = 3404.387, Dev Loss = 87.385,
# Train Accuracy = 0.732, Dev Accuracy = 0.719
# Iteration 100:
# Train Loss = 3245.139, Dev Loss = 83.426,
# Train Accuracy = 0.745, Dev Accuracy = 0.737
# Iteration 110:
# Train Loss = 3109.457, Dev Loss = 80.018,
# Train Accuracy = 0.758, Dev Accuracy = 0.746
# Iteration 120:
# Train Loss = 2992.642, Dev Loss = 77.058,
# Train Accuracy = 0.769, Dev Accuracy = 0.753
# Iteration 130:
# Train Loss = 2891.133, Dev Loss = 74.467,
# Train Accuracy = 0.778, Dev Accuracy = 0.760
# Iteration 140:
# Train Loss = 2802.160, Dev Loss = 72.182,
# Train Accuracy = 0.786, Dev Accuracy = 0.775
# Iteration 150:
# Train Loss = 2723.543, Dev Loss = 70.151,
# Train Accuracy = 0.793, Dev Accuracy = 0.786
# Iteration 160:
# Train Loss = 2653.562, Dev Loss = 68.336,
# Train Accuracy = 0.799, Dev Accuracy = 0.790
# Iteration 170:
# Train Loss = 2590.851, Dev Loss = 66.704,
# Train Accuracy = 0.804, Dev Accuracy = 0.804
# Iteration 180:
# Train Loss = 2534.315, Dev Loss = 65.230,
# Train Accuracy = 0.809, Dev Accuracy = 0.809
# Iteration 190:
# Train Loss = 2483.071, Dev Loss = 63.893,
# Train Accuracy = 0.814, Dev Accuracy = 0.813
# Iteration 200:
# Train Loss = 2436.397, Dev Loss = 62.676,
# Train Accuracy = 0.818, Dev Accuracy = 0.818
# Iteration 210:
# Train Loss = 2393.696, Dev Loss = 61.563,
# Train Accuracy = 0.821, Dev Accuracy = 0.820
# Iteration 220:
# Train Loss = 2354.468, Dev Loss = 60.542,
# Train Accuracy = 0.825, Dev Accuracy = 0.824
# Iteration 230:
# Train Loss = 2318.295, Dev Loss = 59.603,
# Train Accuracy = 0.827, Dev Accuracy = 0.829
# Iteration 240:
# Train Loss = 2284.819, Dev Loss = 58.736,
# Train Accuracy = 0.830, Dev Accuracy = 0.833
# Iteration 250:
# Train Loss = 2253.736, Dev Loss = 57.933,
# Train Accuracy = 0.833, Dev Accuracy = 0.840
# Iteration 260:
# Train Loss = 2224.785, Dev Loss = 57.186,
# Train Accuracy = 0.835, Dev Accuracy = 0.841
# Iteration 270:
# Train Loss = 2197.738, Dev Loss = 56.491,
# Train Accuracy = 0.837, Dev Accuracy = 0.841
# Iteration 280:
# Train Loss = 2172.401, Dev Loss = 55.842,
# Train Accuracy = 0.839, Dev Accuracy = 0.843
# Iteration 290:
# Train Loss = 2148.603, Dev Loss = 55.233,
# Train Accuracy = 0.841, Dev Accuracy = 0.844
# Iteration 300:
# Train Loss = 2126.195, Dev Loss = 54.662,
# Train Accuracy = 0.843, Dev Accuracy = 0.846
# Iteration 310:
# Train Loss = 2105.046, Dev Loss = 54.124,
# Train Accuracy = 0.845, Dev Accuracy = 0.846
# Iteration 320:
# Train Loss = 2085.041, Dev Loss = 53.616,
# Train Accuracy = 0.847, Dev Accuracy = 0.846
# Iteration 330:
# Train Loss = 2066.080, Dev Loss = 53.136,
# Train Accuracy = 0.848, Dev Accuracy = 0.848
# Iteration 340:
# Train Loss = 2048.071, Dev Loss = 52.681,
# Train Accuracy = 0.849, Dev Accuracy = 0.849
# Iteration 350:
# Train Loss = 2030.937, Dev Loss = 52.249,
# Train Accuracy = 0.851, Dev Accuracy = 0.849
# Iteration 360:
# Train Loss = 2014.605, Dev Loss = 51.839,
# Train Accuracy = 0.852, Dev Accuracy = 0.850
# Iteration 370:
# Train Loss = 1999.013, Dev Loss = 51.448,
# Train Accuracy = 0.854, Dev Accuracy = 0.850
# Iteration 380:
# Train Loss = 1984.104, Dev Loss = 51.074,
# Train Accuracy = 0.855, Dev Accuracy = 0.853
# Iteration 390:
# Train Loss = 1969.826, Dev Loss = 50.717,
# Train Accuracy = 0.856, Dev Accuracy = 0.852
# Iteration 400:
# Train Loss = 1956.135, Dev Loss = 50.376,
# Train Accuracy = 0.857, Dev Accuracy = 0.853
# Iteration 410:
# Train Loss = 1942.988, Dev Loss = 50.048,
# Train Accuracy = 0.858, Dev Accuracy = 0.854
# Iteration 420:
# Train Loss = 1930.349, Dev Loss = 49.734,
# Train Accuracy = 0.859, Dev Accuracy = 0.857
# Iteration 430:
# Train Loss = 1918.183, Dev Loss = 49.432,
# Train Accuracy = 0.860, Dev Accuracy = 0.859
# Iteration 440:
# Train Loss = 1906.460, Dev Loss = 49.141,
# Train Accuracy = 0.861, Dev Accuracy = 0.860
# Iteration 450:
# Train Loss = 1895.151, Dev Loss = 48.861,
# Train Accuracy = 0.862, Dev Accuracy = 0.863
# Iteration 460:
# Train Loss = 1884.231, Dev Loss = 48.591,
# Train Accuracy = 0.863, Dev Accuracy = 0.865
# Iteration 470:
# Train Loss = 1873.677, Dev Loss = 48.330,
# Train Accuracy = 0.863, Dev Accuracy = 0.865
# Iteration 480:
# Train Loss = 1863.467, Dev Loss = 48.079,
# Train Accuracy = 0.864, Dev Accuracy = 0.865
# Iteration 490:
# Train Loss = 1853.580, Dev Loss = 47.835,
# Train Accuracy = 0.865, Dev Accuracy = 0.865

# %%
plt.plot(train_accuracies, label='Train Accuracies')
plt.plot(dev_accuracies, label='Dev Accuracies')
plt.title('Accuracies vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(dev_losses, label='Dev Loss')
plt.title('Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
final_predictions = get_predictions(forward_propagation(w1, b1, w2, b2, w3, b3, X_dev, k0, k1)[-1])
f1 = f1_score(Y_dev, final_predictions, average='macro')
print(f"Final F1-Score: {f1}")
# Out:
# Final F1-Score: 0.8648755638179472
